# %%
import os

export_path = "/Volumes/workspace/default/retailmart_raw/gold_exports"

# %%
spark.table("workspace.default.gold_customer360") \
.coalesce(1) \
.write \
.mode("overwrite") \
.option("header", True) \
.csv(export_path + "/customer360")

# %%
spark.table("workspace.default.gold_monthly_sales") \
.coalesce(1) \
.write \
.mode("overwrite") \
.option("header", True) \
.csv(export_path + "/monthly_sales")

# %%
spark.table("workspace.default.gold_product_performance") \
.coalesce(1) \
.write \
.mode("overwrite") \
.option("header", True) \
.csv(export_path + "/product_performance")

# %%
spark.table("workspace.default.gold_payment_summary") \
.coalesce(1) \
.write \
.mode("overwrite") \
.option("header", True) \
.csv(export_path + "/payment_summary")

# %%
spark.table("workspace.default.gold_delivery_performance") \
.coalesce(1) \
.write \
.mode("overwrite") \
.option("header", True) \
.csv(export_path + "/delivery_performance")

# %%
spark.table("workspace.default.gold_kpi_dashboard") \
.coalesce(1) \
.write \
.mode("overwrite") \
.option("header", True) \
.csv(export_path + "/kpi_dashboard")
