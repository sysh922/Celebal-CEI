# %% [markdown]
# load data

# %%
import pandas as pd

customers = pd.read_csv("../data/raw/raw_customers_dataset.csv")
orders = pd.read_csv("../data/raw/raw_orders_dataset.csv")
items = pd.read_csv("../data/raw/raw_items_dataset.csv")
payments = pd.read_csv("../data/raw/raw_payments_dataset.csv")
products = pd.read_csv("../data/raw/raw_products_dataset.csv")

print("All datasets loaded successfully!")
# Out:
# All datasets loaded successfully!
